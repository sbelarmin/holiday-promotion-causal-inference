# %% [markdown]
# ## Data Generation
#
# The following cells will generate the synthetic ecommerce data panel. The data will be saved to "data/raw/holiday_promotion_panel.csv" and should output short data summary.

# %%
import pandas as pd 
import numpy as np 

# %load_ext autoreload
# %autoreload 2
import src.data.make_dataset_v1 as m

# %%
# generate data from make_dataset_v1 module

df = m.generate_panel_synth()
m.quick_sanity_checks(df)
# Out:
# /Users/scottbelarmino/ds_decision_science_exp_repo/holiday-promotion-causal-inference/src/data/make_dataset_v1.py:212: RuntimeWarning: invalid value encountered in divide
#   margin_rate = np.where(net_revenue > 0, margin_dollars / net_revenue, 0.0)
# {'rows': 350000,
#  'unique_users': 10000,
#  'promo_exposure_rate': 0.72612,
#  'pre_exposure_rate': 0.0,
#  'avg_units_pre': 0.4290733333333333,
#  'avg_units_promo_exposed': 0.7939183606015534,
#  'avg_units_promo_unexposed': 0.4823280268730831,
#  'avg_margin_rate_pre': 0.35927136748256533,
#  'avg_margin_rate_promo_exposed': -0.07082418256567642,
#  'avg_margin_rate_promo_unexposed': 0.35868922069737497,
#  'avg_prior_spend_promo_exposed': 79.9827719707961,
#  'avg_prior_spend_promo_unexposed': 57.95292619908141}
